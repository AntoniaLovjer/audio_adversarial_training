# %%
from google.colab import drive
drive.mount('/mydrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /mydrive

# %% [markdown]
# ## Extract data from zip file

# %%
# import package to unzip .7zip file
# !apt-get install p7zip-full
# !ls
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-6).
# 0 upgraded, 0 newly installed, 0 to remove and 28 not upgraded.
# sample_data

# %%
# create local directory and copy zip file into it
# !mkdir /kaggle_audio/
# !cp /mydrive/My\ Drive/DL_Project/03_Speech_to_Text/Speech_Commands_Recognition/datasets/kaggle_audio_dataset/train.7z /kaggle_audio/

# %%
# locally unzip the audio files in train.7z
# !cd /kaggle_audio/ && p7zip -d train.7z
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1121103842 bytes (1070 MiB)
#
# Extracting archive: train.7z
# --
# Path = train.7z
# Type = 7z
# Physical Size = 1121103842
# Headers Size = 389133
# Method = Delta LZMA2:24
# Solid = +
# Blocks = 2
#
# Everything is Ok
#
# Folders: 33
# Files: 64732
# Size:       2055161498
# Compressed: 1121103842

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline

import IPython.display
import numpy as np
import matplotlib.pyplot as plt
import copy
from scipy.io import wavfile
from scipy.signal import butter, lfilter
import scipy.ndimage

# %% [markdown]
# ## Data Loader

# %%
# !cd /kaggle_audio/train && ls
# Out:
# audio  LICENSE	README.md  testing_list.txt  validation_list.txt

# %%
DATADIR = '/kaggle_audio/' # unzipped train and test data
OUTDIR = './model-k' # just a random name
# Data Loading
import os
import re
from glob import glob

POSSIBLE_LABELS = 'yes no up down left right on off stop go silence unknown'.split()
id2name = {i: name for i, name in enumerate(POSSIBLE_LABELS)}
name2id = {name: i for i, name in id2name.items()}

def load_data(data_dir):
    """ Return 2 lists of tuples:
    [(class_id, user_id, path), ...] for train
    [(class_id, user_id, path), ...] for validation
    """
    # Just a simple regexp for paths with three groups:
    # prefix, label, user_id
    pattern = re.compile("(.+\/)?(\w+)\/([^_]+)_.+wav")
    all_files = glob(os.path.join(data_dir, 'train/audio/*/*wav'))

    with open(os.path.join(data_dir, 'train/validation_list.txt'), 'r') as fin:
        validation_files = fin.readlines()
    valset = set()
    for entry in validation_files:
        r = re.match(pattern, entry)
        if r:
            valset.add(r.group(3))

    possible = set(POSSIBLE_LABELS)
    train, val = [], []
    for entry in all_files:
        r = re.match(pattern, entry)
        if r:
            label, uid = r.group(2), r.group(3)
            if label == '_background_noise_':
                label = 'silence'
            if label not in possible:
                label = 'unknown'

            label_id = name2id[label]

            sample = (label_id, uid, entry)
            if uid in valset:
                val.append(sample)
            else:
                train.append(sample)

    print('There are {} train and {} val samples'.format(len(train), len(val)))
    return train, val

trainset, valset = load_data(DATADIR)
# Out:
# There are 57929 train and 6798 val samples

# %%
trainset_sub = trainset[2000:2200]
valset_sub = valset[:10]
trainset_sub
# Out:
# [(11, '7bae88ed', '/kaggle_audio/train/audio/four/7bae88ed_nohash_1.wav'),
#  (11, 'cc71bada', '/kaggle_audio/train/audio/four/cc71bada_nohash_0.wav'),
#  (11, '617de221', '/kaggle_audio/train/audio/four/617de221_nohash_1.wav'),
#  (11, 'f4f59743', '/kaggle_audio/train/audio/four/f4f59743_nohash_1.wav'),
#  (11, 'fb24c826', '/kaggle_audio/train/audio/four/fb24c826_nohash_0.wav'),
#  (11, 'fbf3dd31', '/kaggle_audio/train/audio/four/fbf3dd31_nohash_0.wav'),
#  (11, 'b9db6e42', '/kaggle_audio/train/audio/four/b9db6e42_nohash_0.wav'),
#  (11, 'bab36420', '/kaggle_audio/train/audio/four/bab36420_nohash_2.wav'),
#  (11, '5705a0f9', '/kaggle_audio/train/audio/four/5705a0f9_nohash_1.wav'),
#  (11, '5f47fdf9', '/kaggle_audio/train/audio/four/5f47fdf9_nohash_1.wav'),
#  (11, '637c702a', '/kaggle_audio/train/audio/four/637c702a_nohash_0.wav'),
#  (11, '9a7c1f83', '/kaggle_audio/train/audio/four/9a7c1f83_nohash_1.wav'),
#  (11, 'b49caed3', '/kaggle_audio/train/audio/four/b49caed3_nohash_2.wav'),
#  (11, 'e7ebf59c', '/kaggle_audio/train/audio/four/e7ebf59c_nohash_0.wav'),
#  (11, '6cf5459b', '/kaggle_audio/train/audio/four/6cf5459b_nohash_0.wav'),
#  (11, '71f9bba8', '/kaggle_audio/train/audio/four/71f9bba8_nohash_3.wav'),
#  (11, 'e55a2b20', '/kaggle_audio/train/audio/four/e55a2b20_nohash_2.wav'),
#  (11, '86fa2dcd', '/kaggle_audio/train/audio/four/86fa2dcd_nohash_0.wav'),
#  (11, 'fffcabd1', '/kaggle_audio/train/audio/four/fffcabd1_nohash_0.wav'),
#  (11, 'f810e799', '/kaggle_audio/train/audio/four/f810e799_nohash_1.wav'),
#  (11, '8eb4a1bf', '/kaggle_audio/train/audio/four/8eb4a1bf_nohash_3.wav'),
#  (11, 'dc7ec25b', '/kaggle_audio/train/audio/four/dc7ec25b_nohash_0.wav'),
#  (11, '86b89661', '/kaggle_audio/train/audio/four/86b89661_nohash_1.wav'),
#  (11, '6272b231', '/kaggle_audio/train/audio/four/6272b231_nohash_1.wav'),
#  (11, '42c6fff1', '/kaggle_audio/train/audio/four/42c6fff1_nohash_0.wav'),
#  (11, '520b2c17', '/kaggle_audio/train/audio/four/520b2c17_nohash_0.wav'),
#  (11, '8549f25d', '/kaggle_audio/train/audio/four/8549f25d_nohash_1.wav'),
#  (11, 'b97c9f77', '/kaggle_audio/train/audio/four/b97c9f77_nohash_3.wav'),
#  (11, 'e7ea8b76', '/kaggle_audio/train/audio/four/e7ea8b76_nohash_2.wav'),
#  (11, '2250f5f2', '/kaggle_audio/train/audio/four/2250f5f2_nohash_0.wav'),
#  (11, '7096522d', '/kaggle_audio/train/audio/four/7096522d_nohash_1.wav'),
#  (11, 'b06c19b0', '/kaggle_audio/train/audio/four/b06c19b0_nohash_0.wav'),
#  (11, '742d6431', '/kaggle_audio/train/audio/four/742d6431_nohash_4.wav'),
#  (11, 'e0611c84', '/kaggle_audio/train/audio/four/e0611c84_nohash_1.wav'),
#  (11, '24c9f572', '/kaggle_audio/train/audio/four/24c9f572_nohash_1.wav'),
#  (11, '3efef882', '/kaggle_audio/train/audio/four/3efef882_nohash_0.wav'),
#  (11, 'e82914c0', '/kaggle_audio/train/audio/four/e82914c0_nohash_0.wav'),
#  (11, '5ac04a92', '/kaggle_audio/train/audio/four/5ac04a92_nohash_0.wav'),
#  (11, '4290ca61', '/kaggle_audio/train/audio/four/4290ca61_nohash_0.wav'),
#  (11, 'd069e6ff', '/kaggle_audio/train/audio/four/d069e6ff_nohash_0.wav'),
#  (11, 'd94eb94f', '/kaggle_audio/train/audio/four/d94eb94f_nohash_0.wav'),
#  (11, '063d48cf', '/kaggle_audio/train/audio/four/063d48cf_nohash_1.wav'),
#  (11, '6736bc64', '/kaggle_audio/train/audio/four/6736bc64_nohash_0.wav'),
#  (11, '8134f43f', '/kaggle_audio/train/audio/four/8134f43f_nohash_4.wav'),
#  (11, '62581901', '/kaggle_audio/train/audio/four/62581901_nohash_0.wav'),
#  (11, '8eb4a1bf', '/kaggle_audio/train/audio/four/8eb4a1bf_nohash_4.wav'),
#  (11, 'eb0676ec', '/kaggle_audio/train/audio/four/eb0676ec_nohash_2.wav'),
#  (11, '413bcfe1', '/kaggle_audio/train/audio/four/413bcfe1_nohash_1.wav'),
#  (11, '3a70ab7f', '/kaggle_audio/train/audio/four/3a70ab7f_nohash_2.wav'),
#  (11, '7e1054e7', '/kaggle_audio/train/audio/four/7e1054e7_nohash_0.wav'),
#  (11, 'c9b653a0', '/kaggle_audio/train/audio/four/c9b653a0_nohash_0.wav'),
#  (11, 'ceaadb24', '/kaggle_audio/train/audio/four/ceaadb24_nohash_0.wav'),
#  (11, '2dcb6848', '/kaggle_audio/train/audio/four/2dcb6848_nohash_0.wav'),
#  (11, '333784b7', '/kaggle_audio/train/audio/four/333784b7_nohash_1.wav'),
#  (11, '48a8a69d', '/kaggle_audio/train/audio/four/48a8a69d_nohash_0.wav'),
#  (11, 'b26343e9', '/kaggle_audio/train/audio/four/b26343e9_nohash_0.wav'),
#  (11, '8a1c449e', '/kaggle_audio/train/audio/four/8a1c449e_nohash_0.wav'),
#  (11, 'bbd0bbd0', '/kaggle_audio/train/audio/four/bbd0bbd0_nohash_0.wav'),
#  (11, '15d83b54', '/kaggle_audio/train/audio/four/15d83b54_nohash_0.wav'),
#  (11, 'e41a903b', '/kaggle_audio/train/audio/four/e41a903b_nohash_0.wav'),
#  (11, 'c44d2a58', '/kaggle_audio/train/audio/four/c44d2a58_nohash_0.wav'),
#  (11, 'c0f8f4df', '/kaggle_audio/train/audio/four/c0f8f4df_nohash_0.wav'),
#  (11, '97f4c236', '/kaggle_audio/train/audio/four/97f4c236_nohash_2.wav'),
#  (11, 'b4aa9fef', '/kaggle_audio/train/audio/four/b4aa9fef_nohash_3.wav'),
#  (11, '56f78b7e', '/kaggle_audio/train/audio/four/56f78b7e_nohash_0.wav'),
#  (11, '9a7c1f83', '/kaggle_audio/train/audio/four/9a7c1f83_nohash_0.wav'),
#  (11, '7fa5fa1f', '/kaggle_audio/train/audio/four/7fa5fa1f_nohash_0.wav'),
#  (11, '146d97db', '/kaggle_audio/train/audio/four/146d97db_nohash_0.wav'),
#  (11, 'dff327c5', '/kaggle_audio/train/audio/four/dff327c5_nohash_0.wav'),
#  (11, 'b9515bf3', '/kaggle_audio/train/audio/four/b9515bf3_nohash_0.wav'),
#  (11, 'de4f7798', '/kaggle_audio/train/audio/four/de4f7798_nohash_0.wav'),
#  (11, '1cb788bc', '/kaggle_audio/train/audio/four/1cb788bc_nohash_0.wav'),
#  (11, '106a6183', '/kaggle_audio/train/audio/four/106a6183_nohash_3.wav'),
#  (11, '2313e093', '/kaggle_audio/train/audio/four/2313e093_nohash_1.wav'),
#  (11, '69f609ec', '/kaggle_audio/train/audio/four/69f609ec_nohash_0.wav'),
#  (11, '40115b19', '/kaggle_audio/train/audio/four/40115b19_nohash_1.wav'),
#  (11, '0ac15fe9', '/kaggle_audio/train/audio/four/0ac15fe9_nohash_0.wav'),
#  (11, '3bfd30e6', '/kaggle_audio/train/audio/four/3bfd30e6_nohash_1.wav'),
#  (11, 'd4082f3e', '/kaggle_audio/train/audio/four/d4082f3e_nohash_1.wav'),
#  (11, '708a9569', '/kaggle_audio/train/audio/four/708a9569_nohash_1.wav'),
#  (11, '1995cf9e', '/kaggle_audio/train/audio/four/1995cf9e_nohash_0.wav'),
#  (11, 'c79159aa', '/kaggle_audio/train/audio/four/c79159aa_nohash_1.wav'),
#  (11, '37dca74f', '/kaggle_audio/train/audio/four/37dca74f_nohash_5.wav'),
#  (11, '10ace7eb', '/kaggle_audio/train/audio/four/10ace7eb_nohash_2.wav'),
#  (11, '5c39594f', '/kaggle_audio/train/audio/four/5c39594f_nohash_2.wav'),
#  (11, '3411cf4b', '/kaggle_audio/train/audio/four/3411cf4b_nohash_0.wav'),
#  (11, '019fa366', '/kaggle_audio/train/audio/four/019fa366_nohash_1.wav'),
#  (11, '01bb6a2a', '/kaggle_audio/train/audio/four/01bb6a2a_nohash_1.wav'),
#  (11, 'cb802c63', '/kaggle_audio/train/audio/four/cb802c63_nohash_0.wav'),
#  (11, '93bbf0bd', '/kaggle_audio/train/audio/four/93bbf0bd_nohash_0.wav'),
#  (11, '850e2222', '/kaggle_audio/train/audio/four/850e2222_nohash_0.wav'),
#  (11, 'd486fb84', '/kaggle_audio/train/audio/four/d486fb84_nohash_1.wav'),
#  (11, '84bf12ff', '/kaggle_audio/train/audio/eight/84bf12ff_nohash_0.wav'),
#  (11, 'efbc3952', '/kaggle_audio/train/audio/eight/efbc3952_nohash_2.wav'),
#  (11, '1e31353f', '/kaggle_audio/train/audio/eight/1e31353f_nohash_0.wav'),
#  (11, 'bd061bef', '/kaggle_audio/train/audio/eight/bd061bef_nohash_0.wav'),
#  (11, 'cd7f8c1b', '/kaggle_audio/train/audio/eight/cd7f8c1b_nohash_4.wav'),
#  (11, 'c948d727', '/kaggle_audio/train/audio/eight/c948d727_nohash_1.wav'),
#  (11, '953fe1ad', '/kaggle_audio/train/audio/eight/953fe1ad_nohash_1.wav'),
#  (11, '3a70ab7f', '/kaggle_audio/train/audio/eight/3a70ab7f_nohash_0.wav'),
#  (11, '7e2d5caf', '/kaggle_audio/train/audio/eight/7e2d5caf_nohash_0.wav'),
#  (11, '7f74626f', '/kaggle_audio/train/audio/eight/7f74626f_nohash_1.wav'),
#  (11, 'a879a2c3', '/kaggle_audio/train/audio/eight/a879a2c3_nohash_0.wav'),
#  (11, 'd056d4d8', '/kaggle_audio/train/audio/eight/d056d4d8_nohash_0.wav'),
#  (11, '692a88e6', '/kaggle_audio/train/audio/eight/692a88e6_nohash_4.wav'),
#  (11, '234ab0fb', '/kaggle_audio/train/audio/eight/234ab0fb_nohash_0.wav'),
#  (11, 'e5afa9b0', '/kaggle_audio/train/audio/eight/e5afa9b0_nohash_0.wav'),
#  (11, 'b87bdb22', '/kaggle_audio/train/audio/eight/b87bdb22_nohash_4.wav'),
#  (11, '51055bda', '/kaggle_audio/train/audio/eight/51055bda_nohash_3.wav'),
#  (11, '069ab0d5', '/kaggle_audio/train/audio/eight/069ab0d5_nohash_2.wav'),
#  (11, 'd9b50b8b', '/kaggle_audio/train/audio/eight/d9b50b8b_nohash_0.wav'),
#  (11, '3ec05c3d', '/kaggle_audio/train/audio/eight/3ec05c3d_nohash_0.wav'),
#  (11, 'a4e8a997', '/kaggle_audio/train/audio/eight/a4e8a997_nohash_1.wav'),
#  (11, 'b9515bf3', '/kaggle_audio/train/audio/eight/b9515bf3_nohash_3.wav'),
#  (11, '857366dd', '/kaggle_audio/train/audio/eight/857366dd_nohash_0.wav'),
#  (11, '38d78313', '/kaggle_audio/train/audio/eight/38d78313_nohash_4.wav'),
#  (11, 'b12bef84', '/kaggle_audio/train/audio/eight/b12bef84_nohash_0.wav'),
#  (11, '462e1919', '/kaggle_audio/train/audio/eight/462e1919_nohash_1.wav'),
#  (11, '44dad20e', '/kaggle_audio/train/audio/eight/44dad20e_nohash_1.wav'),
#  (11, 'c518d1b1', '/kaggle_audio/train/audio/eight/c518d1b1_nohash_0.wav'),
#  (11, 'b63fea9e', '/kaggle_audio/train/audio/eight/b63fea9e_nohash_2.wav'),
#  (11, 'c93d5e22', '/kaggle_audio/train/audio/eight/c93d5e22_nohash_2.wav'),
#  (11, '888a0c49', '/kaggle_audio/train/audio/eight/888a0c49_nohash_0.wav'),
#  (11, 'b9515bf3', '/kaggle_audio/train/audio/eight/b9515bf3_nohash_4.wav'),
#  (11, '9dc1889e', '/kaggle_audio/train/audio/eight/9dc1889e_nohash_1.wav'),
#  (11, 'fda46b78', '/kaggle_audio/train/audio/eight/fda46b78_nohash_0.wav'),
#  (11, 'fd395b74', '/kaggle_audio/train/audio/eight/fd395b74_nohash_2.wav'),
#  (11, 'ab76ac76', '/kaggle_audio/train/audio/eight/ab76ac76_nohash_1.wav'),
#  (11, '82305c3a', '/kaggle_audio/train/audio/eight/82305c3a_nohash_1.wav'),
#  (11, '09ddc105', '/kaggle_audio/train/audio/eight/09ddc105_nohash_1.wav'),
#  (11, '9aa21fa9', '/kaggle_audio/train/audio/eight/9aa21fa9_nohash_2.wav'),
#  (11, '8a325749', '/kaggle_audio/train/audio/eight/8a325749_nohash_1.wav'),
#  (11, '4a4e28f1', '/kaggle_audio/train/audio/eight/4a4e28f1_nohash_0.wav'),
#  (11, '7ff085e1', '/kaggle_audio/train/audio/eight/7ff085e1_nohash_0.wav'),
#  (11, '44dad20e', '/kaggle_audio/train/audio/eight/44dad20e_nohash_0.wav'),
#  (11, '83f9c4ab', '/kaggle_audio/train/audio/eight/83f9c4ab_nohash_1.wav'),
#  (11, 'c37a72d3', '/kaggle_audio/train/audio/eight/c37a72d3_nohash_1.wav'),
#  (11, 'a1cff772', '/kaggle_audio/train/audio/eight/a1cff772_nohash_2.wav'),
#  (11, 'afb9e62e', '/kaggle_audio/train/audio/eight/afb9e62e_nohash_0.wav'),
#  (11, '4fd4d073', '/kaggle_audio/train/audio/eight/4fd4d073_nohash_0.wav'),
#  (11, 'd1d3e64d', '/kaggle_audio/train/audio/eight/d1d3e64d_nohash_0.wav'),
#  (11, '78622c2b', '/kaggle_audio/train/audio/eight/78622c2b_nohash_0.wav'),
#  (11, '14df1e28', '/kaggle_audio/train/audio/eight/14df1e28_nohash_0.wav'),
#  (11, '8eb4a1bf', '/kaggle_audio/train/audio/eight/8eb4a1bf_nohash_0.wav'),
#  (11, 'becd5a53', '/kaggle_audio/train/audio/eight/becd5a53_nohash_0.wav'),
#  (11, '274c008f', '/kaggle_audio/train/audio/eight/274c008f_nohash_1.wav'),
#  (11, '10ace7eb', '/kaggle_audio/train/audio/eight/10ace7eb_nohash_4.wav'),
#  (11, '1a673010', '/kaggle_audio/train/audio/eight/1a673010_nohash_0.wav'),
#  (11, 'fafe8101', '/kaggle_audio/train/audio/eight/fafe8101_nohash_0.wav'),
#  (11, 'a709ddd3', '/kaggle_audio/train/audio/eight/a709ddd3_nohash_1.wav'),
#  (11, 'ea356919', '/kaggle_audio/train/audio/eight/ea356919_nohash_0.wav'),
#  (11, 'caf9fceb', '/kaggle_audio/train/audio/eight/caf9fceb_nohash_0.wav'),
#  (11, '1dce06e8', '/kaggle_audio/train/audio/eight/1dce06e8_nohash_0.wav'),
#  (11, '24ad3ebe', '/kaggle_audio/train/audio/eight/24ad3ebe_nohash_0.wav'),
#  (11, '30802c5d', '/kaggle_audio/train/audio/eight/30802c5d_nohash_0.wav'),
#  (11, 'd952a17e', '/kaggle_audio/train/audio/eight/d952a17e_nohash_0.wav'),
#  (11, '70a00e98', '/kaggle_audio/train/audio/eight/70a00e98_nohash_0.wav'),
#  (11, 'e652590d', '/kaggle_audio/train/audio/eight/e652590d_nohash_0.wav'),
#  (11, 'e7d0eb3f', '/kaggle_audio/train/audio/eight/e7d0eb3f_nohash_1.wav'),
#  (11, 'c1d39ce8', '/kaggle_audio/train/audio/eight/c1d39ce8_nohash_1.wav'),
#  (11, 'fad7a69a', '/kaggle_audio/train/audio/eight/fad7a69a_nohash_1.wav'),
#  (11, '329eab8a', '/kaggle_audio/train/audio/eight/329eab8a_nohash_0.wav'),
#  (11, '638548d5', '/kaggle_audio/train/audio/eight/638548d5_nohash_1.wav'),
#  (11, '62ff07ef', '/kaggle_audio/train/audio/eight/62ff07ef_nohash_1.wav'),
#  (11, '61a9f72a', '/kaggle_audio/train/audio/eight/61a9f72a_nohash_0.wav'),
#  (11, '12529547', '/kaggle_audio/train/audio/eight/12529547_nohash_0.wav'),
#  (11, 'c22d3f18', '/kaggle_audio/train/audio/eight/c22d3f18_nohash_2.wav'),
#  (11, '6c968bd9', '/kaggle_audio/train/audio/eight/6c968bd9_nohash_1.wav'),
#  (11, '179a61b7', '/kaggle_audio/train/audio/eight/179a61b7_nohash_2.wav'),
#  (11, 'ec201020', '/kaggle_audio/train/audio/eight/ec201020_nohash_4.wav'),
#  (11, '0a9f9af7', '/kaggle_audio/train/audio/eight/0a9f9af7_nohash_0.wav'),
#  (11, 'cd85758f', '/kaggle_audio/train/audio/eight/cd85758f_nohash_3.wav'),
#  (11, '1b755c65', '/kaggle_audio/train/audio/eight/1b755c65_nohash_0.wav'),
#  (11, '617de221', '/kaggle_audio/train/audio/eight/617de221_nohash_2.wav'),
#  (11, '0d2bcf9d', '/kaggle_audio/train/audio/eight/0d2bcf9d_nohash_2.wav'),
#  (11, 'c4533c47', '/kaggle_audio/train/audio/eight/c4533c47_nohash_0.wav'),
#  (11, 'bbd0bbd0', '/kaggle_audio/train/audio/eight/bbd0bbd0_nohash_2.wav'),
#  (11, 'bfaf2000', '/kaggle_audio/train/audio/eight/bfaf2000_nohash_1.wav'),
#  (11, '3ae5c04f', '/kaggle_audio/train/audio/eight/3ae5c04f_nohash_0.wav'),
#  (11, '92a9c5e6', '/kaggle_audio/train/audio/eight/92a9c5e6_nohash_2.wav'),
#  (11, '5e3dde6b', '/kaggle_audio/train/audio/eight/5e3dde6b_nohash_0.wav'),
#  (11, '8c7b691a', '/kaggle_audio/train/audio/eight/8c7b691a_nohash_0.wav'),
#  (11, '6b889021', '/kaggle_audio/train/audio/eight/6b889021_nohash_1.wav'),
#  (11, '4f2be90f', '/kaggle_audio/train/audio/eight/4f2be90f_nohash_1.wav'),
#  (11, 'b7a0754f', '/kaggle_audio/train/audio/eight/b7a0754f_nohash_2.wav'),
#  (11, '333784b7', '/kaggle_audio/train/audio/eight/333784b7_nohash_2.wav'),
#  (11, '4b39347d', '/kaggle_audio/train/audio/eight/4b39347d_nohash_0.wav'),
#  (11, '3dfd6c23', '/kaggle_audio/train/audio/eight/3dfd6c23_nohash_0.wav'),
#  (11, 'bbbf4fbd', '/kaggle_audio/train/audio/eight/bbbf4fbd_nohash_0.wav'),
#  (11, '1625acd8', '/kaggle_audio/train/audio/eight/1625acd8_nohash_0.wav'),
#  (11, '3e31dffe', '/kaggle_audio/train/audio/eight/3e31dffe_nohash_1.wav'),
#  (11, '4f256313', '/kaggle_audio/train/audio/eight/4f256313_nohash_0.wav'),
#  (11, '42beb5eb', '/kaggle_audio/train/audio/eight/42beb5eb_nohash_1.wav'),
#  (11, '2b3f509b', '/kaggle_audio/train/audio/eight/2b3f509b_nohash_0.wav'),
#  (11, 'd0426d63', '/kaggle_audio/train/audio/eight/d0426d63_nohash_2.wav'),
#  (11, '98582fee', '/kaggle_audio/train/audio/eight/98582fee_nohash_0.wav'),
#  (11, 'eb3f7d82', '/kaggle_audio/train/audio/eight/eb3f7d82_nohash_4.wav'),
#  (11, 'd7467392', '/kaggle_audio/train/audio/eight/d7467392_nohash_0.wav'),
#  (11, 'f44f440f', '/kaggle_audio/train/audio/eight/f44f440f_nohash_1.wav'),
#  (11, '8dd24423', '/kaggle_audio/train/audio/eight/8dd24423_nohash_0.wav')]

# %% [markdown]
# # Import MFCC Package

# %%
# !pip install python_speech_features
# Out:
# Collecting python_speech_features
#   Downloading https://files.pythonhosted.org/packages/ff/d1/94c59e20a2631985fbd2124c45177abaa9e0a4eee8ba8a305aa26fc02a8e/python_speech_features-0.6.tar.gz
# Building wheels for collected packages: python-speech-features
#   Building wheel for python-speech-features (setup.py) ... done
#   Created wheel for python-speech-features: filename=python_speech_features-0.6-cp36-none-any.whl size=5889 sha256=82fa41fe44541e1c8749d14d0b7e69f1b76c4828ba345bcf3ba2872f6951b9b6
#   Stored in directory: /root/.cache/pip/wheels/3c/42/7c/f60e9d1b40015cd69b213ad90f7c18a9264cd745b9888134be
# Successfully built python-speech-features
# Installing collected packages: python-speech-features
# Successfully installed python-speech-features-0.6

# %%
# !git clone https://github.com/jameslyons/python_speech_features
# %cd python_speech_features
# !python setup.py develop
# Out:
# Cloning into 'python_speech_features'...
# remote: Enumerating objects: 427, done.
# remote: Total 427 (delta 0), reused 0 (delta 0), pack-reused 427
# Receiving objects: 100% (427/427), 218.49 KiB | 416.00 KiB/s, done.
# Resolving deltas: 100% (207/207), done.
# /content/python_speech_features
# running develop
# running egg_info
# creating python_speech_features.egg-info
# writing python_speech_features.egg-info/PKG-INFO
# writing dependency_links to python_speech_features.egg-info/dependency_links.txt
# writing requirements to python_speech_features.egg-info/requires.txt
# writing top-level names to python_speech_features.egg-info/top_level.txt
# writing manifest file 'python_speech_features.egg-info/SOURCES.txt'
# writing manifest file 'python_speech_features.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.6/dist-packages/python-speech-features.egg-link (link to .)
# Adding python-speech-features 0.6 to easy-install.pth file
#
# Installed /content/python_speech_features
# Processing dependencies for python-speech-features==0.6
# Searching for scipy==1.3.1
# Best match: scipy 1.3.1
# Adding scipy 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for numpy==1.17.3
# Best match: numpy 1.17.3
# Adding numpy 1.17.3 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.6 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Finished processing dependencies for python-speech-features==0.6

# %%
# %cd ..
# !git clone https://github.com/Tony607/Acoustic_Diagnosis
# %cd Acoustic_Diagnosis
# Out:
# /content
# Cloning into 'Acoustic_Diagnosis'...
# remote: Enumerating objects: 32, done.
# remote: Total 32 (delta 0), reused 0 (delta 0), pack-reused 32
# Unpacking objects: 100% (32/32), done.
# /content/Acoustic_Diagnosis

# %% [markdown]
# # Sequential Model
#
# ### Initialization

# %%
import glob
import pandas as pd
from scipy import stats
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.ops import rnn, rnn_cell
import numpy as np
from sklearn.model_selection import train_test_split
# %matplotlib inline
plt.style.use('ggplot')
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ### Test Data

# %%
# Need current directory to be /content/Acoustic_Diagnosis/
# %cd content/Acoustic_Diagnosis/
base_dir = "./data/"
sound_file_paths = ["new_60Hz_de_10s_22khz.wav","new_60Hz_re_10s_22khz.wav",
                    "used_60Hz_de_10s_22khz.wav","used_60Hz_re_10s_22khz.wav",
                    "red_60Hz_de_10s_22khz.wav","red_60Hz_re_10s_22khz.wav"]
# Output tags
sound_names = ["new","new",
               "used","used",
               "red","red"]

# %% [markdown]
# ### Google Speech Data

# %%
# Need directory to be top level
# %cd ..
base_dir = "./"
sound_names = []
sound_file_paths = []
i = 1
for sample in trainset:
  if i%1 == 0:
    class_id, user_id, filepath = sample
    file_locations,file_names = os.path.split(filepath)
    _,sound_label = os.path.split(file_locations)
    if sound_label in ['yes','no','on','off','left','right','stop','go','up','down']:
      sound_file_paths.append(filepath)
      sound_names.append(sound_label)
  i+=1

print(sound_names[-10:])
sound_file_paths[-10:]
# Out:
# /
# ['no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no']
# ['/kaggle_audio/train/audio/no/1995cf9e_nohash_0.wav',
#  '/kaggle_audio/train/audio/no/c79159aa_nohash_1.wav',
#  '/kaggle_audio/train/audio/no/f292725f_nohash_0.wav',
#  '/kaggle_audio/train/audio/no/10ace7eb_nohash_2.wav',
#  '/kaggle_audio/train/audio/no/5c39594f_nohash_2.wav',
#  '/kaggle_audio/train/audio/no/01bb6a2a_nohash_1.wav',
#  '/kaggle_audio/train/audio/no/cb802c63_nohash_0.wav',
#  '/kaggle_audio/train/audio/no/1df483c0_nohash_2.wav',
#  '/kaggle_audio/train/audio/no/850e2222_nohash_0.wav',
#  '/kaggle_audio/train/audio/no/a3fc7884_nohash_0.wav']

# %% [markdown]
# ### MFCC Feature Extraction

# %%
def feature_normalize(dataset):
    mu = np.mean(dataset, axis=0)
    sigma = np.std(dataset, axis=0)
    return (dataset - mu) / sigma
def windows(data, window_size):
    start = 0
    while start < len(data):
        yield int(start), int(start + window_size)
        start += (window_size / 2) # stepping at half window size
def extract_features(base_dir, sound_file_paths, sound_names ,bands = 20, frames = 41):
    window_size = 512 * (frames - 1)
    mfccs = []
    labels = []
    for i, sound_file_path in enumerate(sound_file_paths):
        sound_file_full_path = os.path.join(base_dir, sound_file_path)
        sound_clip,s = librosa.load(sound_file_full_path)
        sound_clip = feature_normalize(sound_clip)
        label = sound_names[i]
        for (start,end) in windows(sound_clip,window_size):
            if(len(sound_clip[start:end]) == window_size):
                signal = sound_clip[start:end]
                # y: audio time series, sr: sampling rate, n_mfcc: number of MFCCs to return
                # librosa.feature.mfcc() function return numpy array with shape (bands, frames)
                # transpose since the model expects time axis(frames) come first
                mfcc = librosa.feature.mfcc(y=signal, sr=s, n_mfcc = bands).T 
                mfccs.append(mfcc)
                labels.append(label)
    features = np.asarray(mfccs)
    return np.array(features), np.array(labels,dtype = np.str)

def one_hot_encode(labels):
    return np.asarray(pd.get_dummies(labels), dtype = np.float32)

# %%
bands = 20
frames = 41
features,labels = extract_features(base_dir, sound_file_paths, sound_names, bands = bands, frames = frames)
labels = one_hot_encode(labels)

# %%
# %cd content
import pickle

filename = 'training_features'
with open(filename, 'wb') as f:
    pickle.dump(features, f)

filename = 'training_labels'
with open(filename, 'wb') as f:
    pickle.dump(labels, f)

# %%
import pickle

filename = 'training_features'
with open(filename, 'rb') as f:
    features = pickle.load(f)

filename = 'training_labels'
with open(filename, 'rb') as f:
    labels = pickle.load(f)

# %%
unique_labels = set()
for x in sound_names:
    unique_labels.add(x)
print(unique_labels)
len(unique_labels)

# %%
# Display one MFCC feature vector for one frame of one sample
print(features[-1][-1])
print(features.shape)

# %%
X_train, X_test, y_train, y_test = train_test_split(
        features, labels, test_size=0.2, random_state=10)

# %% [markdown]
# ### Build Model

# %%
learning_rate = 0.001
training_iters = 10000
batch_size = 20
display_step = 500

# Network Parameters
n_input = bands 
n_steps = frames
n_hidden = 64
n_classes = labels.shape[1] # new , other , red

# %%
tf.reset_default_graph()
x = tf.placeholder("float", [None, n_steps, n_input])
y = tf.placeholder("float", [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name='keep_prob')

weight = tf.Variable(tf.random_normal([n_hidden, n_classes]))
bias = tf.Variable(tf.random_normal([n_classes]))

# %% [markdown]
# ### RNN

# %%
def lstm_cell(lstm_size, keep_prob):
    cell = tf.contrib.rnn.BasicLSTMCell(lstm_size)
    return tf.contrib.rnn.DropoutWrapper(cell, input_keep_prob = keep_prob)
def RNN(x, weight, bias, keep_prob, num_layers=2):
    lstm_layers = tf.contrib.rnn.MultiRNNCell([lstm_cell(n_hidden, keep_prob) for _ in range(num_layers)])
    output, state = tf.nn.dynamic_rnn(lstm_layers, x, dtype = tf.float32)
    output = tf.transpose(output, [1, 0, 2])
    last = tf.gather(output, int(output.get_shape()[0]) - 1)
    return tf.nn.softmax(tf.matmul(last, weight) + bias)

# %%
prediction = RNN(x, weight, bias, keep_prob)
# Define loss and optimizer
loss_f = -tf.reduce_sum(y * tf.log(prediction))
optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(loss_f)
# Evaluate model
correct_pred = tf.equal(tf.argmax(prediction,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %% [markdown]
# ### Training

# %%
saver = tf.train.Saver()
session=tf.InteractiveSession()
# Initializing the variables
session.run(tf.global_variables_initializer())

for itr in range(training_iters):    
    offset = (itr * batch_size) % (labels.shape[0] - batch_size)
    batch_x = X_train[offset:(offset + batch_size), :, :]
    batch_y = y_train[offset:(offset + batch_size), :]
    _, c = session.run([optimizer, loss_f],feed_dict={x: batch_x, y : batch_y, keep_prob: 0.95})

    if itr % display_step == 0:
        # Calculate batch accuracy
        acc = session.run(accuracy, feed_dict={x: batch_x, y: batch_y, keep_prob: 1})
        # Calculate batch loss
        loss = session.run(loss_f, feed_dict={x: batch_x, y: batch_y, keep_prob: 1})
        print("Iter " + str(itr) + ", Minibatch Loss= " + \
              "{:.6f}".format(loss) + ", Training Accuracy= " + \
              "{:.5f}".format(acc))

print('Test accuracy: ',round(session.run(accuracy, feed_dict={x: X_test, y: y_test, keep_prob: 1}) , 3))
saver.save(session, save_path = "./model/mfcc_audio.ckpt")

# %% [markdown]
# ### Validation

# %% [markdown]
# ##### Validation Data

# %%
test_sound_names = []
test_sound_file_paths = []
i = 1
for sample in valset:
  if i%1 == 0:
    class_id, user_id, filepath = sample
    file_locations,file_names = os.path.split(filepath)
    test_sound_file_paths.append(filepath)
    _,sound_label = os.path.split(file_locations)
    test_sound_names.append(sound_label)
  i+=1

unknowns = ["Unknown"] * len(test_sound_file_paths)

print(test_sound_names[-10:])
test_sound_file_paths[-10:]

# %% [markdown]
# Validate

# %%
test_features,_ = extract_features(base_dir, test_sound_file_paths, unknowns)

# %%
filename = 'testing_features'
with open(filename, 'wb') as f:
    pickle.dump(test_features, f)

# %%
filename = 'testing_features'
with open(filename, 'rb') as f:
    labels = pickle.load(f)

# %%
y_predicts = session.run(prediction, feed_dict={x: test_features, keep_prob: 1})
predicted_logit = stats.mode(np.argmax(y_predicts,1))[0][0]
list_labels = list(unique_labels)
predicted_label = list_labels[predicted_logit]
predicted_probability = stats.mode(np.argmax(y_predicts,1))[1][0] / len(y_predicts)

# %%
(predicted_label, predicted_probability)

# %%
predicted_class = np.argmax(y_predicts,1)
actual_class = np.argmax(one_hot_encode(test_sound_names),1)

correct = 0
wrong = 0

for j in predicted_class:
  if predicted_class[j] == actual_class[j]:
    correct += 1
  else:
    wrong += 1

validation_accuracy = correct / (correct + wrong)
print(validation_accuracy)

# %%
print(y_predicts[1])

# %% [markdown]
# Results:
# Training Accuracy = 91.2%,
# Validation Accuracy = 82.0%, full set
